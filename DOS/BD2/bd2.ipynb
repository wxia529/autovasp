# %%
import sys
sys.path.append('..')
import plot_dos as pltdos
from py4vasp import Calculation
calc = Calculation.from_path('.')

# %%
calc.bandgap.direct()
# Out:
# np.float64(2.5800848448343885)

# %%
calc.dos.print()
# Out:
# spin polarized Dos:
#     energies: [-61.89, 14.82] 4000 points
# projectors:
#     atoms: Fe, Ti, O, N, C, H
#     orbitals: s, py, pz, px, dxy, dyz, dz2, dxz, dx2y2, fy3x2, fxyz, fyz2, fz3, fxz2, fzx2, fx3

# %%
calc.dos.plot(selection="d(Ti, Fe)")

# %%
calc.dos.plot(selection="dxz(Fe), dyz(Fe), dxy(Fe), dz2(Fe), dx2y2(Fe)")

# %%
calc.dos.plot(selection="dxz(Ti), dyz(Ti), dxy(Ti), dz2(Ti), dx2y2(Ti)")

# %%
calc.dos.plot(selection="p(O , N)")

# %%
calc.dos.plot(selection="px(N), py(N), pz(N)")

# %%
pltdos.SHOW_TOTAL_DOS  = False
pltdos.Y_LIM           = [-25, 25]
pltdos.X_LIM           = [-4, 6]
pltdos.GENERAL_FONT_SIZE = 14
pltdos.LEGEND_FONT_SIZE = 8
pltdos.LEGEND_LOC      = 'upper left'
pltdos.ORDER_MODE      = 'manual'
pltdos.MANUAL_ORDER    = ['Fe', 'Ti', 'O', 'N', 'Cl']
pltdos.plot_vasp_dos(calc.dos.to_dict(selection="d(Ti, Fe), p(O, N)"))

# %%
pltdos.SHOW_TOTAL_DOS  = True
pltdos.X_LIM           = [-4, 6]
pltdos.Y_LIM           = [-85, 85]
pltdos.GENERAL_FONT_SIZE = 14
pltdos.LEGEND_FONT_SIZE = 8
pltdos.LEGEND_LOC      = 'upper right'
pltdos.ORDER_MODE      = 'manual'
pltdos.MANUAL_ORDER    = ['Fe', 'Ti', 'O', 'N', 'Cl']
pltdos.plot_vasp_dos(calc.dos.to_dict(selection="d(Ti, Fe), p(O , N)"))
